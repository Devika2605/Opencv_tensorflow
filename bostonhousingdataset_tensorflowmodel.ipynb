# %% [markdown]
# <a href="https://colab.research.google.com/github/Devika2605/Opencv_tensorflow/blob/main/bostonhousingdataset_tensorflowmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Activation
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras import layers

import tensorflow as tf
import matplotlib.pyplot as plt

# %%
SEED_VALUE = 42

# Fix seed to make training deterministic.
np.random.seed(SEED_VALUE)
tf.random.set_seed(SEED_VALUE)

# %%
# Load the Boston housing dataset.
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

print(X_train.shape)
print("\n")
print("Input features: ", X_train[0])
print("\n")
print("Output target: ", y_train[0])
# Out:
# (404, 13)
#
#
# Input features:  [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
#
#
# Output target:  15.2

# %%
boston_features = {
    "Average Number of Rooms": 5,
}

X_train_1d = X_train[:, boston_features["Average Number of Rooms"]]
print(X_train_1d.shape)

X_test_1d = X_test[:, boston_features["Average Number of Rooms"]]
# Out:
# (404,)

# %%
plt.figure(figsize=(15, 5))

plt.xlabel("Average Number of Rooms")
plt.ylabel("Median Price [$K]")
plt.grid("on")
plt.scatter(X_train_1d[:], y_train, color="green", alpha=0.5)

# %%
model = Sequential()

# Define the model consisting of a single neuron.
model.add(Dense(units=1, input_shape=(1,)))

# Display a summary of the model architecture.
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.005), loss="mse")

# %%
history = model.fit(
    X_train_1d,
    y_train,
    batch_size=16,
    epochs=101,
    validation_split=0.3,
)
# Out:
# Epoch 1/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 251.1139 - val_loss: 332.5994
# Epoch 2/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 229.0343 - val_loss: 312.1377
# Epoch 3/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 212.4202 - val_loss: 293.1743
# Epoch 4/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 196.9818 - val_loss: 275.1405
# Epoch 5/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 182.4024 - val_loss: 257.9567
# Epoch 6/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 168.6358 - val_loss: 241.6097
# Epoch 7/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 155.6726 - val_loss: 226.0963
# Epoch 8/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 143.5087 - val_loss: 211.4144
# Epoch 9/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 132.1403 - val_loss: 197.5620
# Epoch 10/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 121.5631 - val_loss: 184.5367
# Epoch 11/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 111.7721 - val_loss: 172.3360
# Epoch 12/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 102.7614 - val_loss: 160.9565
# Epoch 13/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 94.5237 - val_loss: 150.3946
# Epoch 14/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 87.0507 - val_loss: 140.6456
# Epoch 15/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 80.3318 - val_loss: 131.7039
# Epoch 16/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 74.3540 - val_loss: 123.5622
# Epoch 17/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.1015 - val_loss: 116.2112
# Epoch 18/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.5540 - val_loss: 109.6386
# Epoch 19/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.6861 - val_loss: 103.8283
# Epoch 20/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 57.4656 - val_loss: 98.7583
# Epoch 21/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.8521 - val_loss: 94.3995
# Epoch 22/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.7959 - val_loss: 90.7132
# Epoch 23/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 51.2366 - val_loss: 87.6502
# Epoch 24/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.1051 - val_loss: 85.1496
# Epoch 25/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.3258 - val_loss: 83.1419
# Epoch 26/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.8221 - val_loss: 81.5524
# Epoch 27/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5225 - val_loss: 80.3070
# Epoch 28/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.3655 - val_loss: 79.3374
# Epoch 29/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.3022 - val_loss: 78.5844
# Epoch 30/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.2962 - val_loss: 77.9991
# Epoch 31/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.3224 - val_loss: 77.5429
# Epoch 32/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.3642 - val_loss: 77.1855
# Epoch 33/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 48.4114 - val_loss: 76.9039
# Epoch 34/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 48.4581 - val_loss: 76.6807
# Epoch 35/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 48.5009 - val_loss: 76.5025
# Epoch 36/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 48.5384 - val_loss: 76.3593
# Epoch 37/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 48.5701 - val_loss: 76.2435
# Epoch 38/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 48.5963 - val_loss: 76.1490
# Epoch 39/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 48.6173 - val_loss: 76.0715
# Epoch 40/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 48.6338 - val_loss: 76.0072
# Epoch 41/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 48.6463 - val_loss: 75.9536
# Epoch 42/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.6555 - val_loss: 75.9084
# Epoch 43/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6619 - val_loss: 75.8699
# Epoch 44/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6659 - val_loss: 75.8369
# Epoch 45/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6680 - val_loss: 75.8081
# Epoch 46/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6685 - val_loss: 75.7827
# Epoch 47/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6677 - val_loss: 75.7602
# Epoch 48/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6658 - val_loss: 75.7399
# Epoch 49/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6630 - val_loss: 75.7213
# Epoch 50/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.6595 - val_loss: 75.7043
# Epoch 51/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6555 - val_loss: 75.6884
# Epoch 52/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6509 - val_loss: 75.6734
# Epoch 53/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.6460 - val_loss: 75.6592
# Epoch 54/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.6408 - val_loss: 75.6456
# Epoch 55/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.6354 - val_loss: 75.6325
# Epoch 56/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6298 - val_loss: 75.6198
# Epoch 57/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.6240 - val_loss: 75.6074
# Epoch 58/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6180 - val_loss: 75.5953
# Epoch 59/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6120 - val_loss: 75.5834
# Epoch 60/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.6059 - val_loss: 75.5716
# Epoch 61/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5997 - val_loss: 75.5601
# Epoch 62/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5935 - val_loss: 75.5486
# Epoch 63/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.5872 - val_loss: 75.5372
# Epoch 64/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5809 - val_loss: 75.5259
# Epoch 65/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5746 - val_loss: 75.5146
# Epoch 66/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5682 - val_loss: 75.5035
# Epoch 67/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5618 - val_loss: 75.4923
# Epoch 68/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.5554 - val_loss: 75.4812
# Epoch 69/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.5490 - val_loss: 75.4701
# Epoch 70/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5426 - val_loss: 75.4590
# Epoch 71/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.5363 - val_loss: 75.4480
# Epoch 72/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.5299 - val_loss: 75.4370
# Epoch 73/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5234 - val_loss: 75.4260
# Epoch 74/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.5170 - val_loss: 75.4150
# Epoch 75/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5106 - val_loss: 75.4040
# Epoch 76/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.5042 - val_loss: 75.3930
# Epoch 77/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4978 - val_loss: 75.3821
# Epoch 78/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4914 - val_loss: 75.3711
# Epoch 79/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4850 - val_loss: 75.3602
# Epoch 80/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.4786 - val_loss: 75.3492
# Epoch 81/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4722 - val_loss: 75.3383
# Epoch 82/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4658 - val_loss: 75.3274
# Epoch 83/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.4594 - val_loss: 75.3164
# Epoch 84/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4531 - val_loss: 75.3055
# Epoch 85/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4467 - val_loss: 75.2946
# Epoch 86/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4403 - val_loss: 75.2837
# Epoch 87/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.4339 - val_loss: 75.2728
# Epoch 88/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4276 - val_loss: 75.2619
# Epoch 89/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4212 - val_loss: 75.2510
# Epoch 90/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.4148 - val_loss: 75.2401
# Epoch 91/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.4085 - val_loss: 75.2293
# Epoch 92/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.4021 - val_loss: 75.2184
# Epoch 93/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.3957 - val_loss: 75.2075
# Epoch 94/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.3894 - val_loss: 75.1967
# Epoch 95/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.3830 - val_loss: 75.1858
# Epoch 96/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.3767 - val_loss: 75.1750
# Epoch 97/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.3703 - val_loss: 75.1641
# Epoch 98/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.3640 - val_loss: 75.1533
# Epoch 99/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.3577 - val_loss: 75.1425
# Epoch 100/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.3513 - val_loss: 75.1316
# Epoch 101/101
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 48.3450 - val_loss: 75.1208

# %%
def plot_loss(history):
    plt.figure(figsize=(20,5))
    plt.plot(history.history['loss'], 'g', label='Training Loss')
    plt.plot(history.history['val_loss'], 'b', label='Validation Loss')
    plt.xlim([0, 100])
    plt.ylim([0, 300])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

# %%
plot_loss(history)

# %%
# Predict the median price of a home with [3, 4, 5, 6, 7] rooms.
x = np.array([3, 4, 5, 6, 7])
y_pred = model.predict(x)
for idx in range(len(x)):
    predicted_price = y_pred[idx].item()
    print(f"Predicted price of a home with {x[idx]} rooms: ${int(predicted_price * 10) / 10}K")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted price of a home with 3 rooms: $11.3K
# Predicted price of a home with 4 rooms: $14.6K
# Predicted price of a home with 5 rooms: $18.0K
# Predicted price of a home with 6 rooms: $21.3K
# Predicted price of a home with 7 rooms: $24.6K

# %%
# Generate feature data that spans the range of interest for the independent variable.
x = np.linspace(3, 9, 10)

# Use the model to predict the dependent variable.
y = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
def plot_data(x_data, y_data, x, y, title=None):

    plt.figure(figsize=(15,5))
    plt.scatter(x_data, y_data, label='Ground Truth', color='green', alpha=0.5)
    plt.plot(x, y, color='k', label='Model Predictions')
    plt.xlim([3,9])
    plt.ylim([0,60])
    plt.xlabel('Average Number of Rooms')
    plt.ylabel('Price [$K]')
    plt.title(title)
    plt.grid(True)
    plt.legend()

# %%
plot_data(X_train_1d, y_train, x, y, title='Training Dataset')

# %%
plot_data(X_test_1d, y_test, x, y, title='Test Dataset')
